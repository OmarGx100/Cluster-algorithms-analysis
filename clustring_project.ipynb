# %%
import pandas as pd 
import seaborn as sns
import scipy.cluster.hierarchy as sch
from sklearn.cluster import DBSCAN, KMeans, AgglomerativeClustering
from sklearn import datasets, mixture
import numpy as np 
import matplotlib.pyplot as plt

# %%
""" generatin datasets, we choose the size big to see the scalability of the algorithims
but not to big to avoid too long running time """
#=================================================================================================
n_samples = 500 
noisy_circles  = datasets.make_circles(n_samples = n_samples, factor = 0.5, noise = 0.05)
noisy_moon = datasets.make_moons(n_samples = n_samples, noise = 0.05)
blobs = datasets.make_blobs(n_samples = n_samples, random_state = 8)
no_structure = np.random.rand(n_samples, 2) 


# Anisotropicly distributed data
random_state = 170 
x, y = datasets.make_blobs(n_samples = n_samples , random_state = random_state)
transformation = [[0.6, -0.6],[-0.4, 0.8]]
x_aniso = np.dot(x, transformation)
aniso = (x_aniso,y)

# blods with varied variances

varied = datasets.make_blobs(
    n_samples=n_samples, cluster_std=[1.0, 2.5, 0.5], random_state= random_state
)

# %%
""" #plotting the data 

fig, ax = plt.subplots(2, 3)
ax[0][0] = sns.scatterplot(x =noisy_circles[0][:,0], y =noisy_circles[0][:,1], hue = noisy_circles[1])
ax[0][1] = sns.scatterplot(x =noisy_moon[0][:,0], y =noisy_moon[0][:,1], hue = noisy_moon[1])
ax[0][2] = sns.scatterplot(x =blobs[0][:,0], y =blobs[0][:,1], hue = blobs[1])
ax[1][0] = sns.scatterplot(x =no_structure[:,0], y =no_structure[:,1])
ax[1][1] = sns.scatterplot(x =varied[0][:,0], y =varied[0][:,1], hue = varied[1])
ax[1][2] = sns.scatterplot(x =aniso[0][:,0], y =aniso[0][:,1], hue = aniso[1])
plt.show() """
# Out:
# ' #plotting the data \n\nfig, ax = plt.subplots(2, 3)\nax[0][0] = sns.scatterplot(x =noisy_circles[0][:,0], y =noisy_circles[0][:,1], hue = noisy_circles[1])\nax[0][1] = sns.scatterplot(x =noisy_moon[0][:,0], y =noisy_moon[0][:,1], hue = noisy_moon[1])\nax[0][2] = sns.scatterplot(x =blobs[0][:,0], y =blobs[0][:,1], hue = blobs[1])\nax[1][0] = sns.scatterplot(x =no_structure[:,0], y =no_structure[:,1])\nax[1][1] = sns.scatterplot(x =varied[0][:,0], y =varied[0][:,1], hue = varied[1])\nax[1][2] = sns.scatterplot(x =aniso[0][:,0], y =aniso[0][:,1], hue = aniso[1])\nplt.show() '

# %%
sns.scatterplot(x =noisy_circles[0][:,0], y =noisy_circles[0][:,1], hue = noisy_circles[1],palette='viridis')
# Out:
# <Axes: >

# %%
sns.scatterplot(x =noisy_moon[0][:,0], y =noisy_moon[0][:,1], hue = noisy_moon[1],palette='viridis')
# Out:
# <Axes: >

# %%
sns.scatterplot(x =blobs[0][:,0], y =blobs[0][:,1], hue = blobs[1],palette='viridis')
# Out:
# <Axes: >

# %%
sns.scatterplot(x =no_structure[:,0], y =no_structure[:,1],palette='viridis')
# Out:
# C:\Users\omarg\AppData\Local\Temp\ipykernel_29812\1008064602.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x =no_structure[:,0], y =no_structure[:,1],palette='viridis')
# <Axes: >

# %%
sns.scatterplot(x =varied[0][:,0], y =varied[0][:,1], hue = varied[1],palette='viridis')
# Out:
# <Axes: >

# %%
sns.scatterplot(x =aniso[0][:,0], y =aniso[0][:,1], hue = aniso[1],palette='viridis')
# Out:
# <Axes: >

# %%
sns.scatterplot(x =noisy_circles[0][:,0], y =noisy_circles[0][:,1], hue = noisy_circles[1],palette='viridis')
# Out:
# <Axes: >

# %%
dendrogram = sch.dendrogram(sch.linkage(noisy_moon[0], method='centroid'))

# %%
dendrogram = sch.dendrogram(sch.linkage(noisy_moon[0], method='single'))

# %%
#initializing the models 
kmean = KMeans(2)
hier = AgglomerativeClustering(2)
dbscan = DBSCAN(eps=0.2)

# %%
k_means_circles = kmean.fit_predict(noisy_circles[0])
hier_circles = hier.fit_predict(noisy_circles[0])
dbscan_circles = dbscan.fit_predict(noisy_circles[0])
# Out:
# c:\Users\omarg\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
fig, ax = plt.subplots(1,3,figsize = (10,4))
sns.scatterplot(x =noisy_circles[0][:,0], y =noisy_circles[0][:,1], hue = k_means_circles,palette='dark',ax = ax[0])
sns.scatterplot(x =noisy_circles[0][:,0], y =noisy_circles[0][:,1], hue = hier_circles, ax = ax[1])
sns.scatterplot(x =noisy_circles[0][:,0], y =noisy_circles[0][:,1], hue = dbscan_circles,palette='cool', ax = ax[2])

ax[0].set_title("KMEANS")
ax[1].set_title("hierarchy")
ax[2].set_title("BDSCAN")
# Out:
# Text(0.5, 1.0, 'BDSCAN')

# %%
#initializing the models 
kmean = KMeans(2)
hier = AgglomerativeClustering(2)
dbscan = DBSCAN(eps=0.2)

# %%
k_means_moon = kmean.fit_predict(noisy_moon[0])
hier_moon = hier.fit_predict(noisy_moon[0])
dbscan_moon = dbscan.fit_predict(noisy_moon[0])
# Out:
# c:\Users\omarg\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
fig, ax = plt.subplots(1,3,figsize = (10,4))
sns.scatterplot(x =noisy_moon[0][:,0], y =noisy_moon[0][:,1], hue = k_means_moon,palette='dark',ax = ax[0])
sns.scatterplot(x =noisy_moon[0][:,0], y =noisy_moon[0][:,1], hue = hier_moon, ax = ax[1])
sns.scatterplot(x =noisy_moon[0][:,0], y =noisy_moon[0][:,1], hue = dbscan_moon,palette='cool', ax = ax[2])

ax[0].set_title("KMEANS")
ax[1].set_title("hierarchy")
ax[2].set_title("BDSCAN")
# Out:
# Text(0.5, 1.0, 'BDSCAN')

# %%
#initializing the models 
kmean = KMeans(3)
hier = AgglomerativeClustering(3)
dbscan = DBSCAN(eps=1.2)

# %%
k_means_blobs = kmean.fit_predict(blobs[0])
hier_blobs = hier.fit_predict(blobs[0])
dbscan_blobs = dbscan.fit_predict(blobs[0])
# Out:
# c:\Users\omarg\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
fig, ax = plt.subplots(1,3,figsize = (10,4))
sns.scatterplot(x =blobs[0][:,0], y =blobs[0][:,1], hue = k_means_blobs,palette='dark',ax = ax[0])
sns.scatterplot(x =blobs[0][:,0], y =blobs[0][:,1], hue = hier_blobs, ax = ax[1])
sns.scatterplot(x =blobs[0][:,0], y =blobs[0][:,1], hue = dbscan_blobs,palette='cool', ax = ax[2])

ax[0].set_title("KMEANS")
ax[1].set_title("hierarchy")
ax[2].set_title("BDSCAN")
# Out:
# Text(0.5, 1.0, 'BDSCAN')

# %%
#initializing the models 
kmean = KMeans(3)
hier = AgglomerativeClustering(3)
dbscan = DBSCAN(eps=0.85, min_samples=16)

# %%
k_means_varied = kmean.fit_predict(varied[0])
hier_varied = hier.fit_predict(varied[0])
dbscan_varied = dbscan.fit_predict(varied[0])
# Out:
# c:\Users\omarg\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
fig, ax = plt.subplots(1,3,figsize = (10,4))
sns.scatterplot(x =varied[0][:,0], y =varied[0][:,1], hue = k_means_varied,palette='dark',ax = ax[0])
sns.scatterplot(x =varied[0][:,0], y =varied[0][:,1], hue = hier_varied, ax = ax[1],palette='viridis')
sns.scatterplot(x =varied[0][:,0], y =varied[0][:,1], hue = dbscan_varied,palette='viridis', ax = ax[2])

ax[0].set_title("KMEANS")
ax[1].set_title("hierarchy")
ax[2].set_title("BDSCAN")
# Out:
# Text(0.5, 1.0, 'BDSCAN')

# %%
#original Clustring 
sns.scatterplot(x =varied[0][:,0], y =varied[0][:,1], hue = varied[1],palette='viridis')
# Out:
# <Axes: >
